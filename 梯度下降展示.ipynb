# %%
import matplotlib.pyplot as plt
import numpy as np
def fun(x, k):
    return 2*k*x - k**2
X = np.linspace(-2,2,1001)
plt.plot(X, X**2)
X0 = np.random.rand() * 4 - 2
a = 0.1 #学习率
n = 2*X0 #梯度
print(X0)
for i in range(20):
    X0 = X0 - a * n
    plt.plot(X, fun(X, X0), 'ro', markersize = 0.3)
    if abs(X0) <0.01:
        print(X0)
        continue
plt.show()
# Out:
# 0.26246262431529255
# 1.3877787807814457e-17

# %%
import numpy as np
import matplotlib.pyplot as plt
def gradient_descent_model(alpha, iter_max, eta):
    """
    梯度下降算法，求解凸函数(y = x**2 + 2*x + 5)最小值
    alpha过小：迭代次数过多，容易局部收敛。过大：容易在最低点来回震荡
    """
    xi = np.linspace(-6, 4, 100)
    yi = xi**2 + 2 * xi + 5
    x0, y0 = 3, 3**2 + 2 * 3 + 5
    plt.plot(xi, yi)
    plt.show()
    loss = [] #损失函数值列表
    for iter in range(iter_max):
        pass

# %%
alpha = 0.05
iter_max = 1000
eta = 1e-5
gradient_descent_model
